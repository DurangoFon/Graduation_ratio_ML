# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/graduation_rate.csv')
df.head(5)
# Out:
#    ACT composite score  SAT total score parental level of education
# 0                   22             1625                 high school  \
# 1                   29             2090          associate's degree
# 2                   30             2188           bachelor's degree
# 3                   33             2151          associate's degree
# 4                   29             2050          associate's degree
#
#    parental income  high school gpa  college gpa  years to graduate
# 0            40999              3.0          3.1                  7
# 1            75817              4.0          3.4                  5
# 2            82888              4.0          3.9                  3
# 3            93518              4.0          3.7                  5
# 4            79153              4.0          3.4                  6

# %%
df.describe()
# Out:
#        ACT composite score  SAT total score  parental income  high school gpa
# count          1000.000000      1000.000000       1000.00000      1000.000000  \
# mean             28.607000      1999.906000      67377.85200         3.707400
# std               2.774211       145.078361      18827.33105         0.287381
# min              20.000000      1598.000000      18906.00000         2.800000
# 25%              27.000000      1898.000000      54269.75000         3.500000
# 50%              28.500000      2000.000000      67842.50000         3.800000
# 75%              31.000000      2099.000000      80465.50000         4.000000
# max              36.000000      2385.000000     124470.00000         4.000000
#
#        college gpa  years to graduate
# count  1000.000000        1000.000000
# mean      3.376500           4.982000
# std       0.237179           1.414099
# min       2.600000           3.000000
# 25%       3.200000           4.000000
# ...

# %%
sns.displot(data=df, x='ACT composite score', kde = True)
plt.show()

# %%
sns.histplot(data= df, x = 'parental level of education')
plt.xticks(rotation = 90)
plt.show()

# %%
sns.displot(data = df, x = 'years to graduate',kde=True,bins=8)
plt.show()

# %%
sns.displot(data=df,x = 'high school gpa',bins =18,kde=True)
plt.show()

# %%
sns.displot(data = df, x = 'college gpa',kde=True)
plt.show()

# %%
sns.displot(data = df, x = 'parental income',kde = True)
plt.show()

# %%
sns.displot(data = df, x = 'SAT total score', kde = True)
plt.show()

# %% [markdown]
# ## Multivariable analysis

# %%
sns.pairplot(data = df, hue = 'parental level of education')
plt.show()

# %%
sns.scatterplot(data= df,x='years to graduate',y='high school gpa')
plt.show()

# %%
sns.scatterplot(data= df,x='years to graduate',y='college gpa')
plt.show()

# %%
sns.scatterplot(data= df,x='years to graduate',y='SAT total score')
plt.show()

# %%
sns.scatterplot(data= df,x='college gpa', y='ACT composite score')
plt.show()

# %%
sns.scatterplot(data= df,x='years to graduate',y='parental income')
plt.show()

# %%
sns.scatterplot(data= df,x='college gpa', y='parental income')
plt.show()

# %%
sns.scatterplot(data= df,x='high school gpa', y='ACT composite score',hue='parental level of education',palette='coolwarm')
plt.show()

# %%
sns.scatterplot(data= df,x='parental income', y='ACT composite score',hue='parental level of education',palette='coolwarm')
plt.show()
